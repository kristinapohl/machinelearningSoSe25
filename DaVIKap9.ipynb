# %% [markdown]
# <a href="https://colab.research.google.com/github/kristinapohl/machinelearningSoSe25/blob/main/DaVIKap9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Aufgabe_06_1.py ###
# matplotlib-Bibliothek importieren
import matplotlib.pyplot as plt
# NumPy-Bibliothek importieren
import numpy as np

# Vorgegebene Daten
a1    = 10 + 5 * np.random.randn(500)           # Plot oben-links
a2    = np.random.randn(50).cumsum()            # Plot oben-rechts
a34_x = np.arange(30)                           # Plot unten-links, unten-rechts
a34_y = np.arange(30) + 3 * np.random.randn(30) # Plot unten-links, unten-rechts

# %%
# 2x2 Subplots hinzufuegen, gemeinsame X-Achse verwenden
# Diagramme erstellen
#fig, axes = plt.subplots(2,2, sharex = True)
fig =plt.figure()


ax1 = fig.add_subplot(2,2,1)
# mit fig, axes = plt.subplots(2, 2, sharex=True) direkt alle subplots auf einmal generieren
# axes heißen die Objekte
# mit sharex ist die x Achse bei allen plots in den gleichen Dimensionen


# Achsenbeschriftungen hinzufuegen
ax1.set_xlabel('x-Achse')
ax1.set_ylabel('y-Achse')
plt.plot(a1, label = 'a1') #befüllt den aktuellen subplot

ax2 = fig.add_subplot(2,2,2)
#ax2.set_ylabel('y-Achse')
ax2.set_xlabel('x-Achse')
#plt.plot(a2, label = 'a2')
ax2.plot(a2, linestyle='--', color='g', marker='o', label="L-P-Diagramm")



#ax3 = fig.add_subplot(2,2,3)
#ax3.set_ylabel('y-Achse')
#ax3.set_xlabel('x-Achse')
#plt.plot(a34_x , label = 'a34_x')

###ax4 = fig.add_subplot(2,2,4)
#ax4.set_xlabel('x-Achse')
#ax4.set_ylabel('y-Achse')
#ax4.plot()
#plt.plot(a34_y,label = 'a34_y')

# Legende hinzufuegen, Platzierung oben rechts
fig.legend(loc='upper right') # für alle Objekte von fig insgesamt
#ax2.legend(loc='upper right')
##ax3.legend(loc='upper right')
#ax4.legend(loc='upper right')

# %% [markdown]
# for i in range(2):
#   for j in range(2):
#       axes[i,j].hist(a1,a2,a34_x,a34_y)

# %%
# Speichern in ein PNG-Bild ohne dem weissen Rand
png_name = 'Diagramm.png'
plt.savefig(png_name) #, bbox_inches='tight'


### Ende Aufgabe_06_1.py ###
